# %%
# %run '../import_dbase.ipynb'
# %run '../import_dashboard.ipynb'
dashboard('004')
# Out:
# <font size=4><b>Kernel -> Interrupt To Stop</b></font>
#         <style  type="text/css" >
#
#             #T_63e50e5c_58ca_11e6_a3b3_0025907b0d4a tr:hover {
#
#                 background-color: #ffff99;
#
#             }
#
#             #T_63e50e5c_58ca_11e6_a3b3_0025907b0d4a th {
#
#                 font-size: 100%;
#
#                 text-align: center;
#
#             }
#
#             #T_63e50e5c_58ca_11e6_a3b3_0025907b0d4a caption {
#
#                 caption-side: bottom;
#
#             }
#
#
#         </style>
#
#         <table id="T_63e50e5c_58ca_11e6_a3b3_0025907b0d4a" None>
#
#             <caption>Valve State</caption>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">MainGas
#
#                 <th class="col_heading level0 col1">Sys RCT
#
#                 <th class="col_heading level0 col2">Gas Evac
#
#                 <th class="col_heading level0 col3">Hivac
#
# ...
