# %%
# %run 'import_getters.ipynb'

# %%
help(getEvents)
# help(getGasEvents)
# help(getDutyCycleEvents
# help(getPressureEvents)
# help(getSensorData)
# help(getEngData)
# help(getSensorNames)
# help(getMultiEvents)
# Out:
# Help on function getEvents in module __main__:
#
# getEvents(dataBase, path='/home/ihs01/Documents/NOTEBOOKS/DATA/')
#     NAME
#         getEvents
#
#     FILE
#         import_getters.ipynb
#
#     DESCRIPTION
#
#         This function pulls all event data from the pkl file for the specified database and returns a
#         multi-tiered indexed dataframe containing:
#             -eventId     (index)
#             -dataBase    (index)
#             -run         (index)
#             -Start_Time  (column)
#             -Stop_Time   (column)
#             -Duty_Cycle  (column)
#             -Gas         (column)
#             -Pressure    (column)
#
#         If the event ID's do not match when combining START and STOP events it throws an exeption.
#
#     INPUT
#         dataBase: string name of database
#         path:     optional (defaults to '/home/ihs01/Documents/NOTEBOOKS/DATA/')
#
#     RETURN
#         pandas dataframe
#
#     EXAMPLE
#         dataBase ='rct007'
# ...

# %%
dfEvents = getEvents('rct007')

# %%
events=dfEvents.index[0:-1].get_level_values('eventId')
events[-1]
# Out:
# 77

# %%
tuples = dfEvents.index[5]
tuples
# Out:
# (5, 'rct007', '004')

# %%
temp=list(tuples)[-10:-1]

# %%
[e[0] for e in temp]
# Out:
# [69, 70, 71, 72, 73, 74, 75, 76, 77]

# %%
eventTuples = dfEvents.index

# %%
sensor = 'rct_rtd1'
rct_rtd_1_eng = getEngData(sensor, eventTuples[0])
rct_rtd_1_sensor = getSensorData(sensor, eventTuples[0])

# %%
df = getMultiEvent(sensor, 0, 3, eventTuples)
df
# Out:
#                             rct_rtd1  Event ID
# 2016-06-28 00:46:39.556908  17.247    0
# 2016-06-28 00:46:39.989594  17.278    0
# 2016-06-28 00:46:40.422867  17.278    0
# 2016-06-28 00:46:40.856576  17.294    0
# 2016-06-28 00:46:41.289848  17.278    0
# 2016-06-28 00:46:41.723590  17.278    0
# 2016-06-28 00:46:42.156401  17.278    0
# 2016-06-28 00:46:42.631537  17.278    0
# 2016-06-28 00:46:43.065383  17.263    0
# 2016-06-28 00:46:43.523949  17.263    0
# 2016-06-28 00:46:43.956904  17.263    0
# 2016-06-28 00:46:44.390214  17.263    0
# 2016-06-28 00:46:44.840256  17.263    0
# 2016-06-28 00:46:45.283581  17.294    0
# 2016-06-28 00:46:45.708330  17.263    0
# 2016-06-28 00:46:46.142185  17.263    0
# 2016-06-28 00:46:46.616312  17.263    0
# 2016-06-28 00:46:47.050788  17.263    0
# 2016-06-28 00:46:47.483780  17.263    0
# 2016-06-28 00:46:47.925806  17.263    0
# 2016-06-28 00:46:48.367642  17.263    0
# 2016-06-28 00:46:48.809004  17.278    0
# ...
