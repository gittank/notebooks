# %%
# %run import_getters.ipynb
# help(getEvents)

# %%
dataBase = 'rct007'
run = '004'
eventsDf = getEvents(dataBase)

# %%
eventsTuple = eventsDf.index

# %%
# help(getSensorNames)

# %%
sensorNames = getSensorNames(dataBase, run)
# sensorNames
# Out:
#                    sensor
# 0   foreline_valve_closed
# 1   foreline_valve_open
# 2   hivac_valve_closed
# 3   hivac_valve_open
# 4   rough_valve_closed
# 5   rough_valve_open
# 6   sys_rct_valve_closed
# 7   sys_rct_valve_open
# 8   sys_rga_valve_closed
# 9   sys_rga_valve_open
# 10  BaratronPress
# 11  forelinePress
# 12  systemPress
# 13  H2Setpoint
# 14  D2Setpoint
# 15  ARSetpoint
# 16  HeSetpoint
# 17  H2Flowrate
# 18  D2Flowrate
# 19  ARFlowrate
# 20  HeFlowrate
# 21  rct_rtd1
# 22  rct_rtd2
# 23  rct_rtd3
# 24  rct_rtd4
# 25  rct_rtd5
# 26  rct_rtd6
# 27  flowin_rtd
# 28  flowout_rtd
# 29  amb_rtd1
# 30  amb_rtd2
# 31  amb_rtd3
# 32  amb_rtd4
# 33  htr1_tc
# 34  htr2_tc
# 35  spare_tc1
# 36  spare_tc2
# 37  spare_tc3
# 38  spare_tc4
# 39  spare_tc5
# 40  spare_tc6
# 41  htrstate
# 42  htr1duty
# 43  htr2duty
# 44  htrperiod
# 45  htrtimeon
# 46  H2MFCOpen
# 47  D2MFCOpen
# 48  ArMFCOpen
# 49  HeMFCOpen
# 50  ventOpen
# 51  maingasOpen
# 52  SysRctOpen
# 53  EvacOpen
# ...

# %%
valveStates = sensorNames[0:10]
valveStates = valveStates.append(sensorNames[46:60])


pressureSensors = sensorNames[10:13]
pressureSensors = pressureSensors.append(sensorNames[60:62])

mfcFlowRate = sensorNames[13:21]
rtdSensors = sensorNames[21:33]
tcSensors = sensorNames[33:41]
htrStates = sensorNames[41:46]
flowCounter = sensorNames[62:64]
voltageSensors = sensorNames[64:]

# %%
pressureSensors
# Out:
#               sensor
# 10  BaratronPress
# 11  forelinePress
# 12  systemPress
# 60  20TBaratronPress
# 61  sysTurboPress
